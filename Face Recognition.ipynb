# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('../images/multi_faces.jpg')

image_copy = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)

# %%
plt.figure(figsize=(20, 10))
plt.imshow(gray, cmap="gray")

# %%
face_cascade = cv2.CascadeClassifier("../detector_architectures/haarcascade_frontalface_default.xml")

faces = face_cascade.detectMultiScale(gray, 4, 6)

# %%
print("we found {} faces in image".format(len(faces)))
# Out:
# we found 13 faces in image

# %%
image_detector = np.copy(image_copy)

for (x, y, w, h) in faces:
    cv2.rectangle(image_detector, (x, y), (x+w, y+h), (255, 0, 0), 5)
    
plt.figure(figsize=(20, 10))
plt.imshow(image_detector)
